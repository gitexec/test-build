# %%
from neomodel import db
from neomodel import (config, StructuredNode, StringProperty, IntegerProperty,
    UniqueIdProperty, RelationshipTo, RelationshipFrom)
from google.cloud import bigquery
client = bigquery.Client.from_service_account_json(
    'key.json')
import pandas as pd
db.set_connection('bolt://neo4j:Xxw1sY62YHoN@localhost:7687')
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# /usr/local/lib/python3.5/dist-packages/neo4j/bolt/connection.py in _connect(resolved_address, **config)
#     574         log_debug("~~ [CONNECT] %s", resolved_address)
# --> 575         s.connect(resolved_address)
#     576         s.settimeout(t)
#
# ConnectionRefusedError: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# ServiceUnavailable                        Traceback (most recent call last)
# <ipython-input-72-0b231ce24580> in <module>
#       6     'key.json')
#       7 import pandas as pd
# ----> 8 db.set_connection('bolt://neo4j:Xxw1sY62YHoN@localhost:7687')
#
# /usr/local/lib/python3.5/dist-packages/neomodel/util.py in set_connection(self, url)
#      93                                            auth=basic_auth(username, password),
#      94                                            encrypted=config.ENCRYPTED_CONNECTION,
# ---> 95                                            max_pool_size=config.MAX_POOL_SIZE)
#      96         self.url = url
#      97         self._pid = os.getpid()
#
# /usr/local/lib/python3.5/dist-packages/neo4j/v1/api.py in driver(cls, uri, **config)
#      92         :class:`.Driver` subclass instance directly.
#      93         """
# ---> 94         return Driver(uri, **config)
#      95
#      96
#
# /usr/local/lib/python3.5/dist-packages/neo4j/v1/api.py in __new__(cls, uri, **config)
#     131         for subclass in Driver.__subclasses__():
#     132             if parsed.scheme == subclass.uri_scheme:
# --> 133                 return subclass(uri, **config)
#     134         raise ValueError("URI scheme %r not supported" % parsed.scheme)
#     135
#
# /usr/local/lib/python3.5/dist-packages/neo4j/v1/direct.py in __new__(cls, uri, **config)
#      71
#      72         pool = DirectConnectionPool(connector, instance.address, **config)
# ---> 73         pool.release(pool.acquire())
#      74         instance._pool = pool
#      75         instance._max_retry_time = config.get("max_retry_time", default_config["max_retry_time"])
#
# /usr/local/lib/python3.5/dist-packages/neo4j/v1/direct.py in acquire(self, access_mode)
#      42
#      43     def acquire(self, access_mode=None):
# ---> 44         return self.acquire_direct(self.address)
#      45
#      46
#
# /usr/local/lib/python3.5/dist-packages/neo4j/bolt/connection.py in acquire_direct(self, address)
#     448                 if can_create_new_connection:
#     449                     try:
# --> 450                         connection = self.connector(address, self.connection_error_handler)
#     451                     except ServiceUnavailable:
#     452                         self.remove(address)
#
# /usr/local/lib/python3.5/dist-packages/neo4j/v1/direct.py in connector(address, error_handler)
#      68
#      69         def connector(address, error_handler):
# ---> 70             return connect(address, security_plan.ssl_context, error_handler, **config)
#      71
#      72         pool = DirectConnectionPool(connector, instance.address, **config)
#
# /usr/local/lib/python3.5/dist-packages/neo4j/bolt/connection.py in connect(address, ssl_context, error_handler, **config)
#     702         raise ServiceUnavailable("Failed to resolve addresses for %s" % address)
#     703     else:
# --> 704         raise last_error
#
# /usr/local/lib/python3.5/dist-packages/neo4j/bolt/connection.py in connect(address, ssl_context, error_handler, **config)
#     692         log_debug("~~ [RESOLVED] %s -> %s", address, resolved_address)
#     693         try:
# --> 694             s = _connect(resolved_address, **config)
#     695             s, der_encoded_server_certificate = _secure(s, address[0], ssl_context, **config)
#     696             connection = _handshake(s, resolved_address, der_encoded_server_certificate, error_handler, **config)
#
# /usr/local/lib/python3.5/dist-packages/neo4j/bolt/connection.py in _connect(resolved_address, **config)
#     582         _force_close(s)
#     583         if error.errno in (61, 99, 111, 10061):
# --> 584             raise ServiceUnavailable("Failed to establish connection to {!r} (reason {})".format(resolved_address, error.errno))
#     585         else:
#     586             raise
#
# ServiceUnavailable: Failed to establish connection to ('127.0.0.1', 7687) (reason 111)

# %%
QUERY = """WITH cust AS (SELECT * FROM `raw.Customers`) select * from cust"""
customers = pd.read_gbq(query=QUERY,
                        project_id='front-icentris',
                        private_key='key.json',
                        dialect='standard')
customers
# Out:
# /usr/local/lib/python3.5/dist-packages/pandas/io/gbq.py:149: FutureWarning: private_key is deprecated and will be removed in a future version.Use the credentials argument instead. See https://pandas-gbq.readthedocs.io/en/latest/howto/authentication.html for examples on using the credentials argument with service account keys.
#   credentials=credentials, verbose=verbose, private_key=private_key)
#         CustomerID          FirstName MiddleName     LastName NameSuffix  \
# 0          1091072              Kenya                  McIver
# 1          1112279              Karla                    Nunn
# 2          1193612            Quinton                Privette
# 3          1198018            Sabrina                  Vargas
# 4          1201778             Debbie             Vigil-Ortiz
# 5           813643   Brandon & Angela                  Strobl
# 6           814297              Moses          C         Hall
# 7           814322             IDLife               Champions
# 8           815194              Terri                 Hammack
# 9           816910             Steven                Weissman
# 10          819990             Austin                 Walters
# 11          823147              Karli                   Riley
# 12          900942              henry                   yepez
# 13          901109              Jason                Jennings
# 14          902327              Tammy               Cangelose
# 15          935697               Tony                 Hammock
# 16          962463             Pierre                Koncurat
# 17         1217574          Deborah A                  Rucano
# 18         1227680           Adrienne              Somerville
# 19         1229281             Alissa                  Newell
# 20         1229988              Brady               Retterath
# 21         1244303               Tara                Thompson
# 22         1260767           Danielle                   Busby
# 23         1261366               Jeff                  Rogers
# 24          969276               jill                  austin
# 25          994355             Glenda                  Miller
# 26         1277154           Superior             Urgent Care
# 27         1292417              Jason               Stoughton
# 28         1299378              Susan                   Lopez
# 29         1302179  Parish Management             Consultants
# ...            ...                ...        ...          ...        ...
# 410423     1199989              Kelly                    Wood
# 410424     1195226            Matthew                  Porter
# 410425     1203352              Tina                   Flores
# 410426     1189853            Patrick                  Pierre
# 410427     1190085               Rose                   11417
# 410428     1201569            Daniela               Sepulveda
# 410429     1188539             Hollie                   Ashby
# 410430     1198138            Melissa                 Johnson
# 410431     1200660              Marty                 Jackson
# 410432     1195492          Mischelle                  Stotts
# 410433     1198058           Danielle                 Sposito
# 410434     1198107              Asong                  Defang
# 410435     1198885             Daniel                 Kraning
# 410436     1201513       Margarita B.                 Vergara
# 410437     1203504              Cecil                   Henry
# 410438     1062768               jade                 pereira
# 410439     1062043               Tony               Romo TEST
# 410440     1063743              Karla                  Deleon
# 410441     1062752               jade                 pereira
# 410442     1064181                Jim                Bob TEST
# 410443     1064913                Amy                 Wendler
# 410444     1063509               Eric                   Smith
# 410445     1062749               jade                 pereira
# 410446     1064080              Joyce                 Overton
# 410447     1062389              Donna              Kaczmarski
# 410448     1063511               Eric                   Smith
# 410449      901138             Shelly                  Rogers
# 410450      905403              Katie                 Englund
# 410451      900299             Stacey                 Loggins
# 410452      905404              Katie                 Englund
#
#                                    Company  CustomerTypeID  CustomerStatusID  \
# 0                                                        5                 1
# 1                                                        5                 1
# 2                                                        5                 1
# 3                                                        5                 1
# 4                                                        5                 1
# 5                                                        5                 1
# 6                                                        5                 1
# 7                                                        5                 1
# 8                   National Power Brokers               5                 1
# 9                                                        5                 1
# 10                                                       5                 1
# 11                                                       2                 1
# 12                                                       1                 1
# 13                                                       1                 1
# 14                                                       1                 1
# 15                                                       5                 1
# 16                                                       5                 1
# 17                                                       5                 1
# 18                                                       1                 2
# 19                                                       5                 1
# 20                                                       5                 1
# 21                                                       5                 1
# 22                                                       5                 1
# 23                                                       5                 1
# 24                                                       5                 1
# 25                                                       5                 1
# 26      Doctors for a Better Tomorrow PLLC              10                 1
# 27                                                       5                 1
# 28                                                       5                 1
# 29                                                       6                 1
# ...                                    ...             ...               ...
# 410423                                                   1                 2
# 410424                                                   5                 2
# 410425                                                   5                 2
# 410426                                                   5                 2
# 410427                                                   5                 2
# 410428                                                   5                 2
# 410429                                                   2                 2
# 410430                                                   5                 2
# 410431                                                   1                 2
# 410432                                                   5                 2
# 410433                                                   5                 2
# 410434                                                   2                 2
# 410435                                                   2                 2
# 410436                                                   5                 2
# 410437                                                   5                 2
# 410438                                                   1                 2
# 410439                                                   5                 2
# 410440                                                   7                 2
# 410441                                                   1                 2
# 410442                                                   5                 2
# 410443                                                   1                 2
# 410444                                                   1                 2
# 410445                                                   1                 2
# 410446                                                   1                 2
# 410447                                                   1                 2
# 410448                                                   1                 2
# 410449                                                   1                 2
# 410450                                                   4                 2
# 410451                                                   5                 2
# 410452                                                   4                 2
#
#                                         Email         Phone  ... Date4 Date5  \
# 0                         chefkem@hotmail.com  757-218-0027  ...  None  None
# 1                         karla@karlanunn.com  214-282-8359  ...  None  None
# 2                       qprivette20@yahoo.com  919-671-9393  ...  None  None
# 3                       vargasbrina@gmail.com  609-968-9310  ...  None  None
# 4                           debv777@gmail.com  505-440-7897  ...  None  None
# 5                          BAStrobl@gmail.com    9038910486  ...  None  None
# 6                       moseshall34@yahoo.com  337-348-4433  ...  None  None
# 7                darlene.unclebach@idlife.com  214-629-5411  ...  None  None
# 8                      terrihammack@gmail.com                ...  None  None
# 9                           s.weissman@me.com                ...  None  None
# 10                  austinwalters14@gmail.com                ...  None  None
# 11                   jared.riley@icentris.com    1231231234  ...  None  None
# 12                        eyepez718@gmail.com                ...  None  None
# 13                    jjennings.jfd@gmail.com                ...  None  None
# 14              tcangelose@arubapetroleum.com                ...  None  None
# 15                     tonyh@idlifeoffice.com  417-755-0700  ...  None  None
# 16                                pjrk@me.com  610-688-8899  ...  None  None
# 17                        drucano@stny.rr.com  607-621-5498  ...  None  None
# 18                                               2402986885  ...  None  None
# 19                       adnewell09@gmail.com    8324076652  ...  None  None
# 20      kristinretterathphotography@gmail.com    6058504715  ...  None  None
# 21                          thomtar@gmail.com  832-341-8946  ...  None  None
# 22                 danielle@itsabuzzworld.com  337-802-4643  ...  None  None
# 23                       j.zimbabwe@yahoo.com  210-389-3717  ...  None  None
# 24                    jillaustin.ny@gmail.com    6072278180  ...  None  None
# 25                     hendricksranch@msn.com  817-247-0545  ...  None  None
# 26                   info@superiorclinics.com  817-476-4050  ...  None  None
# 27                 Jason.Stoughton@icloud.com   678-873-728  ...  None  None
# 28                   susanlopez2911@gmail.com  346-315-5572  ...  None  None
# 29          parishmanagement@idlifeoffice.com  504-262-9019  ...  None  None
# ...                                       ...           ...  ...   ...   ...
# 410423                                           9802261718  ...  None  None
# 410424                                         412-215-1639  ...  None  None
# 410425                                         409-939-4385  ...  None  None
# 410426                                         301-661-1685  ...  None  None
# 410427                                          11111111111  ...  None  None
# 410428                                         713-653-3033  ...  None  None
# 410429                                         410-766-6446  ...  None  None
# 410430                                         678-521-0183  ...  None  None
# 410431                                           6784169434  ...  None  None
# 410432                                         614-783-0305  ...  None  None
# 410433                                         614-314-7599  ...  None  None
# 410434                                           2404215094  ...  None  None
# 410435                                         410-222-7933  ...  None  None
# 410436                                         972-754-9461  ...  None  None
# 410437                                           8705525534  ...  None  None
# 410438                                         610-506-5195  ...  None  None
# 410439                                                       ...  None  None
# 410440                                           7133739091  ...  None  None
# 410441                                           6105065195  ...  None  None
# 410442                                                       ...  None  None
# 410443                                           2149952727  ...  None  None
# 410444                                         301-341-2614  ...  None  None
# 410445                                           6105065195  ...  None  None
# 410446                                           6788607961  ...  None  None
# 410447                                         559-312-6119  ...  None  None
# 410448                                         301-341-2614  ...  None  None
# 410449                                                       ...  None  None
# 410450                                                       ...  None  None
# 410451                                         469-422-0828  ...  None  None
# 410452                                                       ...  None  None
#
#           CreatedDate   ModifiedDate           CreatedBy  \
# 0       1449848336000  1552230813900  API - API_Icentris
# 1       1454764460000  1552240742880  API - API_Icentris
# 2       1486049487000  1552321086160  API - API_iCentris
# 3       1488217060000  1551933663570  API - API_iCentris
# 4       1489771491000  1552086562487  API - API_iCentris
# 5       1334448000000  1490201479137              IMPORT
# 6       1339459200000  1490201479137              IMPORT
# 7       1339718400000  1552321923760              IMPORT
# 8       1351641600000  1490201479137              IMPORT
# 9       1382400000000  1490201479137              IMPORT
# 10      1385769600000  1552482227577              IMPORT
# 11      1389968820000  1490201479137  API - API_Icentris
# 12      1390078978950  1453987704440  API - API_Icentris
# 13      1390087061247  1409213811317  API - API_Icentris
# 14      1390208106273  1453480205140  API - API_Icentris
# 15      1398657823000  1552055290217  API - API_Icentris
# 16      1407927193000  1552397561660  API - API_Icentris
# 17      1494413966000  1551975076497  API - API_iCentris
# 18      1497956697483  1501245108043  API - API_iCentris
# 19      1498579164000  1552297152390  API - API_iCentris
# 20      1498819343000  1552471131420  API - API_iCentris
# 21      1505919423000  1551820868410  API - API_iCentris
# 22      1515761900000  1551996050367  API - API_iCentris
# 23      1516113200000  1552377955093  API - API_iCentris
# 24      1411070347000  1552494820193  API - API_Icentris
# 25      1420905619000  1552037418660  API - API_Icentris
# 26      1525267797000  1526032931707  API - API_iCentris
# 27      1534863159000  1552401818703  API - API_iCentris
# 28      1540906777000  1552331535417  API - API_iCentris
# 29      1544517757000  1544698942647  API - API_iCentris
# ...               ...            ...                 ...
# 410423  1489057930000  1551807707387  API - API_iCentris
# 410424  1486905861000  1551807707387  API - API_iCentris
# 410425  1490268061000  1551807707387  API - API_iCentris
# 410426  1484238402000  1551807707387  API - API_iCentris
# 410427  1484362671000  1551807707387  API - API_iCentris
# 410428  1489684422000  1551807707387  API - API_iCentris
# 410429  1483552123000  1551807707387  API - API_iCentris
# 410430  1488272838000  1551807707387  API - API_iCentris
# 410431  1489352297023  1551807707387  API - API_iCentris
# 410432  1487030242000  1551807707387  API - API_iCentris
# 410433  1488225186000  1551807707387  API - API_iCentris
# 410434  1488233659000  1551807707387  API - API_iCentris
# 410435  1488549973000  1551807707387  API - API_iCentris
# 410436  1489669926000  1551807707387  API - API_iCentris
# 410437  1490298735000  1551807707387  API - API_iCentris
# 410438  1442535109000  1443700587773  API - API_Icentris
# 410439  1442328393000  1443700587773              KatieR
# 410440  1442912130647  1443700587773  API - API_Icentris
# 410441  1442527462377  1443700587773  API - API_Icentris
# 410442  1443016095000  1443700587773              KatieR
# 410443  1443272988500  1443700587773  API - API_Icentris
# 410444  1442836385530  1443700587773  API - API_Icentris
# 410445  1442527397530  1443700587773  API - API_Icentris
# 410446  1443001020487  1443700587773  API - API_Icentris
# 410447  1442425529000  1443700587773  API - API_Icentris
# 410448  1442836497530  1443700587773  API - API_Icentris
# 410449  1390090134480  1392290918910  API - API_Icentris
# 410450  1390513136717  1392290918910  API - API_Icentris
# 410451  1390060011933  1392290918910  API - API_Icentris
# 410452  1390513216697  1392290918910  API - API_Icentris
#
#                       ModifiedBy EmailUnsubscribeDate EmailSubscribeDate  \
# 0       API - MobileExigoCoreApi                  NaN       1.449848e+12
# 1             API - API_iCentris                  NaN       1.454764e+12
# 2       API - MobileExigoCoreApi                  NaN                NaN
# 3       API - MobileExigoCoreApi                  NaN                NaN
# 4             API - API_iCentris                  NaN                NaN
# 5                        tk85832         1.389954e+12                NaN
# 6                        tk85832         1.389954e+12                NaN
# 7                   thomas.odell         1.389954e+12                NaN
# 8                        tk85832         1.389954e+12                NaN
# 9                        tk85832         1.389954e+12                NaN
# 10                   kara.hudson         1.389954e+12                NaN
# 11                       tk85832                  NaN       1.389969e+12
# 12                   unsubscribe         1.453988e+12       1.390079e+12
# 13                       Unknown                  NaN       1.390087e+12
# 14                       Unknown                  NaN       1.390208e+12
# 15              Lorena.Hernandez                  NaN       1.398658e+12
# 16              Lorena.Hernandez                  NaN       1.407927e+12
# 17                    dlattimore                  NaN                NaN
# 18                       Unknown         1.501243e+12                NaN
# 19                   kara.hudson                  NaN                NaN
# 20                  thomas.odell                  NaN                NaN
# 21      API - MobileExigoCoreApi                  NaN                NaN
# 22            API - API_iCentris                  NaN                NaN
# 23                   kara.hudson                  NaN                NaN
# 24      API - MobileExigoCoreApi                  NaN       1.411070e+12
# 25                  austin.odell                  NaN       1.420906e+12
# 26                    Commission                  NaN                NaN
# 27                      Tk119804                  NaN                NaN
# 28      API - MobileExigoCoreApi                  NaN                NaN
# 29                    Commission                  NaN                NaN
# ...                          ...                  ...                ...
# 410423                  Tk119804         1.497280e+12                NaN
# 410424                  Tk119804         1.491835e+12                NaN
# 410425                  Tk119804         1.494939e+12                NaN
# 410426                  Tk119804         1.489484e+12                NaN
# 410427                  Tk119804         1.535124e+12                NaN
# 410428                  Tk119804         1.489770e+12                NaN
# 410429                  Tk119804         1.521451e+12                NaN
# 410430                  Tk119804         1.494939e+12                NaN
# 410431                  Tk119804         1.493050e+12                NaN
# 410432                  Tk119804         1.495637e+12                NaN
# 410433                  Tk119804         1.491835e+12                NaN
# 410434                  Tk119804         1.490183e+12                NaN
# 410435                  Tk119804         1.495033e+12                NaN
# 410436                  Tk119804         1.510583e+12                NaN
# 410437                  Tk119804         1.497282e+12                NaN
# 410438                Commission         1.443539e+12       1.442535e+12
# 410439                Commission         1.442331e+12                NaN
# 410440                Commission         1.443083e+12       1.442912e+12
# 410441                Commission         1.443539e+12       1.442527e+12
# 410442                Commission         1.443016e+12                NaN
# 410443                Commission         1.443432e+12       1.443273e+12
# 410444                Commission         1.442840e+12       1.442836e+12
# 410445                Commission         1.443539e+12       1.442527e+12
# 410446                Commission         1.443101e+12       1.443001e+12
# 410447                Commission         1.442511e+12       1.442426e+12
# 410448                Commission         1.442840e+12       1.442836e+12
# 410449                Commission         1.392221e+12       1.390090e+12
# 410450                Commission         1.392290e+12       1.390513e+12
# 410451                Commission         1.392242e+12       1.390060e+12
# 410452                Commission         1.392290e+12       1.390513e+12
#
#        SMSSubscribeDate SMSUnsubscribeDate
# 0                  None               None
# 1                  None               None
# 2                  None               None
# 3                  None               None
# 4                  None               None
# 5                  None               None
# 6                  None               None
# 7                  None               None
# 8                  None               None
# 9                  None               None
# 10                 None               None
# 11                 None               None
# 12                 None               None
# 13                 None               None
# 14                 None               None
# 15                 None               None
# 16                 None               None
# 17                 None               None
# 18                 None               None
# 19                 None               None
# 20                 None               None
# 21                 None               None
# 22                 None               None
# 23                 None               None
# 24                 None               None
# 25                 None               None
# 26                 None               None
# 27                 None               None
# 28                 None               None
# 29                 None               None
# ...                 ...                ...
# 410423             None               None
# 410424             None               None
# 410425             None               None
# 410426             None               None
# 410427             None               None
# 410428             None               None
# 410429             None               None
# 410430             None               None
# 410431             None               None
# 410432             None               None
# 410433             None               None
# 410434             None               None
# 410435             None               None
# 410436             None               None
# 410437             None               None
# 410438             None               None
# 410439             None               None
# 410440             None               None
# 410441             None               None
# 410442             None               None
# 410443             None               None
# 410444             None               None
# 410445             None               None
# 410446             None               None
# 410447             None               None
# 410448             None               None
# 410449             None               None
# 410450             None               None
# 410451             None               None
# 410452             None               None
#
# [410453 rows x 95 columns]

# %%
dt = customers.dtypes

# %%
def map_dtypes(name, columns, dtypes):
    mapping = {'int64': 'IntegerProperty', 'object': 'StringProperty',
               'bool': "BooleanProperty", 'float64': 'FloatProperty'}
    mapping_class = 'class {}(StructuredNode):'.format(name)
    for col, prop in zip(columns, dtypes):
        dest_type = mapping.get(prop.name)
        mapping_class += '\n    {} = {}()'.format(col.lower(), dest_type)
    return mapping_class

# %%
cust_class = map_dtypes('Customer', customers.columns, customers.dtypes)

# %%
print(cust_class)
# Out:
# class Customer(StructuredNode):
#     customerid = IntegerProperty()
#     firstname = StringProperty()
#     middlename = StringProperty()
#     lastname = StringProperty()
#     namesuffix = StringProperty()
#     company = StringProperty()
#     customertypeid = IntegerProperty()
#     customerstatusid = IntegerProperty()
#     email = StringProperty()
#     phone = StringProperty()
#     phone2 = StringProperty()
#     mobilephone = StringProperty()
#     fax = StringProperty()
#     mainaddress1 = StringProperty()
#     mainaddress2 = StringProperty()
#     mainaddress3 = StringProperty()
#     maincity = StringProperty()
#     mainstate = StringProperty()
#     mainzip = StringProperty()
#     maincountry = StringProperty()
#     maincounty = StringProperty()
#     mainverified = BooleanProperty()
#     mailaddress1 = StringProperty()
#     mailaddress2 = StringProperty()
#     mailaddress3 = StringProperty()
#     mailcity = StringProperty()
#     mailstate = StringProperty()
#     mailzip = StringProperty()
#     mailcountry = StringProperty()
#     mailcounty = StringProperty()
#     mailverified = BooleanProperty()
#     otheraddress1 = StringProperty()
#     otheraddress2 = StringProperty()
#     otheraddress3 = StringProperty()
#     othercity = StringProperty()
#     otherstate = StringProperty()
#     otherzip = StringProperty()
#     othercountry = StringProperty()
#     othercounty = StringProperty()
#     otherverified = BooleanProperty()
#     canlogin = BooleanProperty()
#     loginname = StringProperty()
#     passwordhash = StringProperty()
#     rankid = FloatProperty()
#     enrollerid = IntegerProperty()
#     sponsorid = IntegerProperty()
#     birthdate = FloatProperty()
#     currencycode = StringProperty()
#     payabletoname = StringProperty()
#     defaultwarehouseid = FloatProperty()
#     payabletypeid = IntegerProperty()
#     checkthreshold = StringProperty()
#     languageid = FloatProperty()
#     gender = StringProperty()
#     taxcode = StringProperty()
#     taxcodetypeid = IntegerProperty()
#     issalestaxexempt = BooleanProperty()
#     salestaxcode = StringProperty()
#     salestaxexemptexpiredate = StringProperty()
#     vatregistration = StringProperty()
#     binaryplacementtypeid = IntegerProperty()
#     usebinaryholdingtank = BooleanProperty()
#     isinbinaryholdingtank = BooleanProperty()
#     isemailsubscribed = BooleanProperty()
#     emailsubscribeip = StringProperty()
#     issmssubscribed = BooleanProperty()
#     notes = StringProperty()
#     field1 = StringProperty()
#     field2 = StringProperty()
#     field3 = StringProperty()
#     field4 = StringProperty()
#     field5 = StringProperty()
#     field6 = StringProperty()
#     field7 = StringProperty()
#     field8 = StringProperty()
#     field9 = StringProperty()
#     field10 = StringProperty()
#     field11 = StringProperty()
#     field12 = StringProperty()
#     field13 = StringProperty()
#     field14 = StringProperty()
#     field15 = StringProperty()
#     date1 = FloatProperty()
#     date2 = StringProperty()
#     date3 = StringProperty()
#     date4 = StringProperty()
#     date5 = StringProperty()
#     createddate = IntegerProperty()
#     modifieddate = IntegerProperty()
#     createdby = StringProperty()
#     modifiedby = StringProperty()
#     emailunsubscribedate = FloatProperty()
#     emailsubscribedate = FloatProperty()
#     smssubscribedate = StringProperty()
#     smsunsubscribedate = StringProperty()

# %%
from neomodel import RelationshipTo, RelationshipFrom, UniqueIdProperty
from neomodel.properties import *
class Customer(StructuredNode):
    uuid = UniqueIdProperty()
    customerid = IntegerProperty(unique_index=True)
    firstname = StringProperty()
    middlename = StringProperty()
    lastname = StringProperty()
    namesuffix = StringProperty()
    company = StringProperty()
    customertypeid = IntegerProperty()
    customerstatusid = IntegerProperty()
    email = StringProperty(unique_index=True)
    phone = StringProperty()
    phone2 = StringProperty()
    mobilephone = StringProperty()
    fax = StringProperty()
    mainaddress1 = StringProperty()
    mainaddress2 = StringProperty()
    mainaddress3 = StringProperty()
    maincity = StringProperty()
    mainstate = StringProperty()
    mainzip = StringProperty()
    maincountry = StringProperty()
    maincounty = StringProperty()
    mainverified = BooleanProperty()
    mailaddress1 = StringProperty()
    mailaddress2 = StringProperty()
    mailaddress3 = StringProperty()
    mailcity = StringProperty()
    mailstate = StringProperty()
    mailzip = StringProperty()
    mailcountry = StringProperty()
    mailcounty = StringProperty()
    mailverified = BooleanProperty()
    otheraddress1 = StringProperty()
    otheraddress2 = StringProperty()
    otheraddress3 = StringProperty()
    othercity = StringProperty()
    otherstate = StringProperty()
    otherzip = StringProperty()
    othercountry = StringProperty()
    othercounty = StringProperty()
    otherverified = BooleanProperty()
    canlogin = BooleanProperty()
    loginname = StringProperty()
    passwordhash = StringProperty()
    rankid = FloatProperty()
    enrollerid = IntegerProperty(unique_index=True)
    sponsorid = IntegerProperty(unique_index=True)
    birthdate = FloatProperty()
    currencycode = StringProperty()
    payabletoname = StringProperty()
    defaultwarehouseid = FloatProperty()
    payabletypeid = IntegerProperty()
    checkthreshold = StringProperty()
    languageid = FloatProperty()
    gender = StringProperty()
    taxcode = StringProperty()
    taxcodetypeid = IntegerProperty()
    issalestaxexempt = BooleanProperty()
    salestaxcode = StringProperty()
    salestaxexemptexpiredate = StringProperty()
    vatregistration = StringProperty()
    binaryplacementtypeid = IntegerProperty()
    usebinaryholdingtank = BooleanProperty()
    isinbinaryholdingtank = BooleanProperty()
    isemailsubscribed = BooleanProperty()
    emailsubscribeip = StringProperty()
    issmssubscribed = BooleanProperty()
    notes = StringProperty()
    field1 = StringProperty()
    field2 = StringProperty()
    field3 = StringProperty()
    field4 = StringProperty()
    field5 = StringProperty()
    field6 = StringProperty()
    field7 = StringProperty()
    field8 = StringProperty()
    field9 = StringProperty()
    field10 = StringProperty()
    field11 = StringProperty()
    field12 = StringProperty()
    field13 = StringProperty()
    field14 = StringProperty()
    field15 = StringProperty()
    date1 = FloatProperty()
    date2 = StringProperty()
    date3 = StringProperty()
    date4 = StringProperty()
    date5 = StringProperty()
    createddate = IntegerProperty()
    modifieddate = IntegerProperty()
    createdby = StringProperty()
    modifiedby = StringProperty()
    emailunsubscribedate = FloatProperty()
    emailsubscribedate = FloatProperty()
    smssubscribedate = StringProperty()
    smsunsubscribedate = StringProperty()
    sponsored_by = RelationshipFrom('Customer', 'sponsored_by')
    sponsoring = RelationshipTo('Customer', 'sponsoring')

# %%
#del db._NODE_CLASS_REGISTRY[frozenset({'Customer'})]
from neomodel import core
#core.drop_indexes()
core.remove_all_labels()
# Out:
# Droping constraints...
#
# Droping indexes...

# %%
for cust in Customer.nodes.all():
    cust.delete()
# Out:
# ---------------------------------------------------------------------------
# ServiceUnavailable                        Traceback (most recent call last)
# <ipython-input-71-db56f629bc70> in <module>
# ----> 1 for cust in Customer.nodes.all():
#       2     cust.delete()
#
# /usr/local/lib/python3.5/dist-packages/neomodel/match.py in all(self, lazy)
#     470         :rtype: list
#     471         """
# --> 472         return self.query_cls(self).build_ast()._execute(lazy)
#     473
#     474     def __iter__(self):
#
# /usr/local/lib/python3.5/dist-packages/neomodel/match.py in _execute(self, lazy)
#     445             self._ast['return'] = 'id({})'.format(self._ast['return'])
#     446         query = self.build_query()
# --> 447         results, _ = db.cypher_query(query, self._query_params, resolve_objects=True)
#     448         # The following is not as elegant as it could be but had to be copied from the
#     449         # version prior to cypher_query with the resolve_objects capability.
#
# /usr/local/lib/python3.5/dist-packages/neomodel/util.py in wrapper(self, *args, **kwargs)
#      30         if not _db.url:
#      31             _db.set_connection(config.DATABASE_URL)
# ---> 32         return func(self, *args, **kwargs)
#      33
#      34     return wrapper
#
# /usr/local/lib/python3.5/dist-packages/neomodel/util.py in cypher_query(self, query, params, handle_unique, retry_on_session_expire, resolve_objects)
#     210             start = time.time()
#     211             response = session.run(query, params)
# --> 212             results, meta = [list(r.values()) for r in response], response.keys()
#     213             end = time.time()
#     214
#
# /usr/local/lib/python3.5/dist-packages/neomodel/util.py in <listcomp>(.0)
#     210             start = time.time()
#     211             response = session.run(query, params)
# --> 212             results, meta = [list(r.values()) for r in response], response.keys()
#     213             end = time.time()
#     214
#
# /usr/local/lib/python3.5/dist-packages/neo4j/v1/api.py in records(self)
#     727             self._session.send()
#     728         while attached():
# --> 729             self._session.fetch()
#     730             while records:
#     731                 yield next_record()
#
# /usr/local/lib/python3.5/dist-packages/neo4j/v1/api.py in fetch(self)
#     338         """
#     339         if self._connection:
# --> 340             detail_count, _ = self._connection.fetch()
#     341             return detail_count
#     342         return 0
#
# /usr/local/lib/python3.5/dist-packages/neo4j/bolt/connection.py in fetch(self)
#     285     def fetch(self):
#     286         try:
# --> 287             return self._fetch()
#     288         except self.error_handler.known_errors as error:
#     289             self.error_handler.handle(error, self.address)
#
# /usr/local/lib/python3.5/dist-packages/neo4j/bolt/connection.py in _fetch(self)
#     302             return 0, 0
#     303
# --> 304         self._receive()
#     305
#     306         details, summary_signature, summary_metadata = self._unpack()
#
# /usr/local/lib/python3.5/dist-packages/neo4j/bolt/connection.py in _receive(self)
#     340             self._defunct = True
#     341             self.close()
# --> 342             raise self.Error("Failed to read from defunct connection {!r}".format(self.server.address))
#     343
#     344     def _unpack(self):
#
# ServiceUnavailable: Failed to read from defunct connection Address(host='::1', port=7687, flow_info=0, scope_id=0)

# %%
for index, row in customers.iterrows():
    try:
        properties = {col.lower(): getattr(row, col) for col in customers.columns}
        customer = Customer(**properties)
        customer.save()
    except Exception as e:
        print(row)
        raise(e)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.5/dist-packages/neomodel/properties.py in _validator(self, value, obj, rethrow)
#     122             try:
# --> 123                 return fn(self, value)
#     124             except Exception as e:
#
# /usr/local/lib/python3.5/dist-packages/neomodel/properties.py in deflate(self, value)
#     329     def deflate(self, value):
# --> 330         return int(value)
#     331
#
# ValueError: cannot convert float NaN to integer
#
# During handling of the above exception, another exception occurred:
#
# DeflateError                              Traceback (most recent call last)
# <ipython-input-70-b9867016cd12> in <module>
#       2     properties = {col.lower(): getattr(row, col) for col in customers.columns}
#       3     customer = Customer(**properties)
# ----> 4     customer.save()
#
# /usr/local/lib/python3.5/dist-packages/neomodel/hooks.py in hooked(self)
#      12         fn_name = getattr(fn, 'func_name', fn.__name__)
#      13         _exec_hook('pre_' + fn_name, self)
# ---> 14         val = fn(self)
#      15         _exec_hook('post_' + fn_name, self)
#      16         return val
#
# /usr/local/lib/python3.5/dist-packages/neomodel/core.py in save(self)
#     531                 self.__class__.__name__))
#     532         else:  # create
# --> 533             self.id = self.create(self.__properties__)[0].id
#     534         return self
#
# /usr/local/lib/python3.5/dist-packages/neomodel/core.py in create(cls, *props, **kwargs)
#     327
#     328         results = []
# --> 329         for item in [cls.deflate(p, obj=_UnsavedNode(), skip_empty=True) for p in props]:
#     330             node, _ = db.cypher_query(query, {'create_params': item})
#     331             results.extend(node[0])
#
# /usr/local/lib/python3.5/dist-packages/neomodel/core.py in <listcomp>(.0)
#     327
#     328         results = []
# --> 329         for item in [cls.deflate(p, obj=_UnsavedNode(), skip_empty=True) for p in props]:
#     330             node, _ = db.cypher_query(query, {'create_params': item})
#     331             results.extend(node[0])
#
# /usr/local/lib/python3.5/dist-packages/neomodel/properties.py in deflate(cls, properties, obj, skip_empty)
#      82             db_property = property.db_property or name
#      83             if properties.get(name) is not None:
# ---> 84                 deflated[db_property] = property.deflate(properties[name], obj)
#      85             elif property.has_default:
#      86                 deflated[db_property] = property.deflate(
#
# /usr/local/lib/python3.5/dist-packages/neomodel/properties.py in _validator(self, value, obj, rethrow)
#     123                 return fn(self, value)
#     124             except Exception as e:
# --> 125                 raise exc_class(self.name, self.owner, str(e), obj)
#     126         else:
#     127             # For using with ArrayProperty where we don't want an Inflate/Deflate error.
#
# DeflateError: Attempting to deflate property 'sponsorid' on <unsaved node> of class 'Customer': cannot convert float NaN to integer

# %%
for cust in  Customer.nodes.all():
    cust.delete()

# %%
all_cust = Customer.nodes.all()
cust = all_cust[0]
cust
# Out:
# <Customer: {'taxcode': '', 'phone2': '', 'otherzip': '', 'isinbinaryholdingtank': False, 'phone': '', 'rankid': 0.0, 'othercounty': '', 'field12': '', 'mobilephone': '', 'namesuffix': '', 'emailsubscribeip': None, 'company': 'Company', 'isemailsubscribed': False, 'mainstate': '', 'mailcountry': '', 'maincity': '', 'smsunsubscribedate': None, 'issalestaxexempt': False, 'otheraddress3': '', 'modifieddate': 1547113429633, 'emailunsubscribedate': 1381334280000.0, 'canlogin': True, 'birthdate': -2208988800000.0, 'mailstate': '', 'mailcity': '', 'mailaddress2': '', 'defaultwarehouseid': None, 'customerstatusid': 1, 'field13': '', 'sponsorid': 4, 'payabletoname': '', 'mainzip': '', 'payabletypeid': 1, 'otherstate': '', 'createdby': 'SETUP', 'smssubscribedate': None, 'currencycode': 'usd', 'field6': '', 'fax': '', 'mainverified': False, 'mailaddress3': '', 'othercity': '', 'languageid': nan, 'emailsubscribedate': None, 'date5': None, 'field7': '', 'mainaddress1': '', 'maincounty': '', 'field3': '', 'date3': None, 'issmssubscribed': False, 'date4': None, 'field8': '', 'mailaddress1': '', 'taxcodetypeid': 1, 'field15': '', 'otheraddress1': '', 'otheraddress2': '', 'mainaddress2': '', 'enrollerid': 4, 'field11': '', 'uuid': 'ca28ee1a885f43f083e505ca2bf92a45', 'email': '', 'loginname': 'IDLIFE10825', 'notes': None, 'otherverified': False, 'field10': '', 'othercountry': '', 'maincountry': '', 'usebinaryholdingtank': False, 'mailzip': '', 'mailverified': False, 'firstname': 'Company', 'field1': '1', 'gender': 'U', 'field5': '', 'customertypeid': 1, 'middlename': '', 'field14': '', 'field2': '', 'mailcounty': '', 'vatregistration': '', 'salestaxexemptexpiredate': None, 'field4': '', 'mainaddress3': '', 'lastname': 'Account', 'date2': None, 'customerid': 5, 'binaryplacementtypeid': 4, 'checkthreshold': '0.0000', 'createddate': 1367798400000, 'passwordhash': "b')\\xa7:\\xdf\\xc5\\xa5Y\\x85\\x00\\x0c\\x1fC?f?\\x1c?7\\x1f1J\\x82\\xdf )\\x82C@'", 'date1': nan, 'salestaxcode': '', 'modifiedby': 'API - MobileExigoCoreApi', 'id': 0, 'field9': ''}>

# %%
QUERY = """WITH cust AS (SELECT * FROM `raw.UniLevelTree`) select * from cust where customerid"""
tree  =  pd.read_gbq(query=QUERY,
                        project_id='front-icentris',
                        private_key='key.json',
                        dialect='standard')
tree

# %%
for index, row in tree.iterrows():
    id = row['CustomerID']
    sponsor_id = row['SponsorID']
    left = row['Lft']
    right = row['Rgt']
    try:
        if id == 0:
            continue
        customer = Customer.nodes.get(customerid=id)
        sponsor = Customer.nodes.get_or_none(customerid=sponsor_id)
        if sponsor:
            customer.sponsored_by.connect(sponsor)
        left_sub = Customer.nodes.get_or_none(customerid=left)
        right_sub = Customer.nodes.get_or_none(customerid=right)
        if left_sub:
            customer.sponsoring.connect(left_sub)
        if right_sub:
            customer.sponsoring.connect(right_sub)
    except Exception as e:
        print("ROW IS : {}".format(row))
        raise(e)

# %%
customer = Customer.nodes.get(customerid=3)

# %%
customer.sponsored_by.all()
# Out:
# []
